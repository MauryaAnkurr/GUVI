# %% [markdown]
# Python Classes
# **bold text**

# %%
class MobileApp:
  def __init__(self,name):
    self.name = name

# %%
new_phone = MobileApp('I phone')

# %%
print(new_phone)
print(type(new_phone))
# Out:
# <__main__.MobileApp instance at 0x7fe34bcffb00>
# <type 'instance'>

# %%
new_phone
# Out:
# <__main__.MobileApp instance at 0x7fe34bcffb00>

# %% [markdown]
# ***Numpy***

# %%
import numpy as np

# %%
X = np.array([1,2,3])

# %%
print(type(X))
# Out:
# <type 'numpy.ndarray'>
